# %%
import gymnasium as gym
from stable_baselines3 import PPO
from src.enforcement_learning.traffic_env import TrafficEnv

env = TrafficEnv()

model = PPO("MlpPolicy", env, verbose=1)
model.learn(total_timesteps=10000)

model.save("../models/ppo_traffic_signal")
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -279     |
# | time/              |          |
# |    fps             | 3127     |
# |    iterations      | 1        |
# |    time_elapsed    | 0        |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | -237        |
# | time/                   |             |
# |    fps                  | 1505        |
# |    iterations           | 2           |
# |    time_elapsed         | 2           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.011514168 |
# |    clip_fraction        | 0.265       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.683      |
# |    explained_variance   | 0.00426     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.75e+03    |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0334     |
# |    value_loss           | 5.03e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | -183        |
# | time/                   |             |
# |    fps                  | 1449        |
# |    iterations           | 3           |
# |    time_elapsed         | 4           |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.015689122 |
# |    clip_fraction        | 0.207       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.651      |
# |    explained_variance   | 0.0369      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 525         |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0317     |
# |    value_loss           | 1.7e+03     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | -131        |
# | time/                   |             |
# |    fps                  | 1528        |
# |    iterations           | 4           |
# |    time_elapsed         | 5           |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.022304513 |
# |    clip_fraction        | 0.166       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.589      |
# |    explained_variance   | 0.0108      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 275         |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0246     |
# |    value_loss           | 697         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | -103        |
# | time/                   |             |
# |    fps                  | 1578        |
# |    iterations           | 5           |
# |    time_elapsed         | 6           |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.016366487 |
# |    clip_fraction        | 0.193       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.522      |
# |    explained_variance   | 0.00507     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 164         |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0193     |
# |    value_loss           | 352         |
# -----------------------------------------

# %%
import numpy as np
env = TrafficEnv()

state, _ = env.reset()
total_reward = 0

for _ in range(50):
    action, _ = model.predict(state)
    state, reward, done, _, _ = env.step(action)
    total_reward += reward
    env.render()
    if done:
        break

print(f"Total Reward: {total_reward}")
# Out:
# Traffic State: [0 0]
# Traffic State: [0 2]
# Traffic State: [0 0]
# Traffic State: [0 0]
# Traffic State: [0 0]
# Traffic State: [0 0]
# Traffic State: [0 0]
# Traffic State: [0 1]
# Traffic State: [0 0]
# Traffic State: [2 4]
# Traffic State: [0 0]
# Traffic State: [0 0]
# Traffic State: [0 4]
# Traffic State: [0 0]
# Traffic State: [0 0]
# Traffic State: [0 0]
# Traffic State: [0 0]
# Traffic State: [0 0]
# Traffic State: [2 0]
# Traffic State: [3 0]
# Traffic State: [0 0]
# Traffic State: [0 0]
# Traffic State: [1 1]
# Traffic State: [0 0]
# Traffic State: [4 0]
# Traffic State: [8 4]
# Traffic State: [8 5]
# Traffic State: [1 0]
# Traffic State: [0 0]
# Traffic State: [0 0]
# Traffic State: [1 0]
# Traffic State: [5 2]
# Traffic State: [7 3]
# Traffic State: [0 0]
# Traffic State: [0 0]
# Traffic State: [0 0]
# Traffic State: [0 0]
# Traffic State: [0 0]
# Traffic State: [0 0]
# Traffic State: [0 0]
# Traffic State: [0 0]
# Traffic State: [0 0]
# Traffic State: [0 0]
# Traffic State: [0 0]
# Traffic State: [1 2]
# Traffic State: [0 0]
# Traffic State: [1 0]
# Traffic State: [0 0]
# Traffic State: [0 0]
# Traffic State: [0 0]
# Total Reward: -72

# %%
from src.vision.detector import count_vehicles

print(count_vehicles("ultralytics/assets/bus.jpg"))
# Output: [5, 3]
# Out:
# WARNING ⚠️ 'source' is missing. Using 'source=/Users/khurshed/PycharmProjects/SmartTraffic/.venv/lib/python3.9/site-packages/ultralytics/assets'.
#
# image 1/2 /Users/khurshed/PycharmProjects/SmartTraffic/.venv/lib/python3.9/site-packages/ultralytics/assets/bus.jpg: 640x480 4 persons, 1 bus, 1 stop sign, 131.8ms
# [ WARN:0@65339.076] global loadsave.cpp:268 findDecoder imread_('ultralytics/assets/bus.jpg'): can't open/read file: check file path/integrity
# image 2/2 /Users/khurshed/PycharmProjects/SmartTraffic/.venv/lib/python3.9/site-packages/ultralytics/assets/zidane.jpg: 384x640 2 persons, 1 tie, 81.4ms
# Speed: 7.1ms preprocess, 106.6ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[16], line 3
#       1 from src.vision.detector import count_vehicles
# ----> 3 print(count_vehicles("ultralytics/assets/bus.jpg"))
#       4 # Output: [5, 3]
#
# File ~/PycharmProjects/SmartTraffic/src/vision/detector.py:25, in count_vehicles(image_path)
#      23 center_x = int(box.xywh[0][0])
#      24 # Simple rule: left = lane 0, right = lane 1
# ---> 25 if center_x < image.shape[1] // 2:
#      26     vehicle_count[0] += 1
#      27 else:
#
# AttributeError: 'NoneType' object has no attribute 'shape'
